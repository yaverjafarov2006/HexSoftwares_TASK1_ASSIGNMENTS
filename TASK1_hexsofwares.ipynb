# %%
import pandas as pd 
import numpy as np

# %%
d= pd.read_csv(r"C:\Users\Baku\Downloads\cars.csv")

# %%
d
# Out:
#         ID                       Model  Year   Condition  Fuel Type  \
# 0        1            Toyota Camry GLE  2023        used     Hybrid
# 1        2     BMW X5 Series xDrive40i  2020        used   gasoline
# 2        3  Mercedes-Benz SS-Class 320  2020  New (Zero)   gasoline
# 3        4     Toyota Land Cruiser VXR  2014        used   gasoline
# 4        5        Jeep Gladiator Sport  2021  New (Zero)   gasoline
# ...    ...                         ...   ...         ...        ...
# 2090  2091       Mitsubishi Galant GTS  2006        used   gasoline
# 2091  2092       Renault Clio Standard  2009        used   gasoline
# 2092  2093                      Daewoo  1997        used   gasoline
# 2093  2094             Ford Fusion SEL  2018        used     Hybrid
# 2094  2095                    Zicker X  2024  New (Zero)  undefined
#
#                    Mileage Seller Type             Location       Price  \
# 0       70,000 - 79,999 km  subjective       Ramtha, Ramtha  22,500 JOD
# ...

# %%
d.isna().sum()
# Out:
# ID              0
# Model           0
# Year            0
# Condition       0
# Fuel Type       0
# Mileage         0
# Seller Type     0
# Location        0
# Price           5
# Insurance       0
# Transmission    0
# Color           0
# dtype: int64

# %%
d=d.dropna()

# %%
d.isna().sum()
# Out:
# ID              0
# Model           0
# Year            0
# Condition       0
# Fuel Type       0
# Mileage         0
# Seller Type     0
# Location        0
# Price           0
# Insurance       0
# Transmission    0
# Color           0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2090 entries, 0 to 2094
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            2090 non-null   int64
#  1   Model         2090 non-null   object
#  2   Year          2090 non-null   int64
#  3   Condition     2090 non-null   object
#  4   Fuel Type     2090 non-null   object
#  5   Mileage       2090 non-null   object
#  6   Seller Type   2090 non-null   object
#  7   Location      2090 non-null   object
#  8   Price         2090 non-null   object
#  9   Insurance     2090 non-null   object
#  10  Transmission  2090 non-null   object
#  11  Color         2090 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 212.3+ KB

# %%
d.head()
# Out:
#    ID                       Model  Year   Condition Fuel Type  \
# 0   1            Toyota Camry GLE  2023        used    Hybrid
# 1   2     BMW X5 Series xDrive40i  2020        used  gasoline
# 2   3  Mercedes-Benz SS-Class 320  2020  New (Zero)  gasoline
# 3   4     Toyota Land Cruiser VXR  2014        used  gasoline
# 4   5        Jeep Gladiator Sport  2021  New (Zero)  gasoline
#
#                 Mileage Seller Type           Location       Price  \
# 0    70,000 - 79,999 km  subjective     Ramtha, Ramtha  22,500 JOD
# 1  100,000 - 109,999 km   undefined   Amman, the chair  64,399 JOD
# 2    40,000 - 49,999 km   an agency      Amman, Abdoun   9,500 JOD
# 3  100,000 - 109,999 km   undefined  Amman, Al-Jubaiha  53,000 JOD
# 4    30,000 - 39,999 km   an agency      Amman, Khalda  37,000 JOD
#
#       Insurance Transmission  Color
# 0  No insurance    Automatic  white
# 1  No insurance    Automatic  beige
# 2  No insurance    Automatic  brown
# 3  No insurance    Automatic  white
# ...

# %%
d.describe()
# Out:
#                 ID         Year
# count  2090.000000  2090.000000
# mean   1048.191866  2016.009091
# std     604.947048     7.884361
# min       1.000000  1965.000000
# 25%     525.250000  2012.000000
# 50%    1047.500000  2018.000000
# 75%    1571.750000  2022.000000
# max    2095.000000  2025.000000

# %%
d
# Out:
#         ID                       Model  Year   Condition  Fuel Type  \
# 0        1            Toyota Camry GLE  2023        used     Hybrid
# 1        2     BMW X5 Series xDrive40i  2020        used   gasoline
# 2        3  Mercedes-Benz SS-Class 320  2020  New (Zero)   gasoline
# 3        4     Toyota Land Cruiser VXR  2014        used   gasoline
# 4        5        Jeep Gladiator Sport  2021  New (Zero)   gasoline
# ...    ...                         ...   ...         ...        ...
# 2090  2091       Mitsubishi Galant GTS  2006        used   gasoline
# 2091  2092       Renault Clio Standard  2009        used   gasoline
# 2092  2093                      Daewoo  1997        used   gasoline
# 2093  2094             Ford Fusion SEL  2018        used     Hybrid
# 2094  2095                    Zicker X  2024  New (Zero)  undefined
#
#                    Mileage Seller Type             Location       Price  \
# 0       70,000 - 79,999 km  subjective       Ramtha, Ramtha  22,500 JOD
# ...

# %%
d["Price"]=d["Price"].str.replace(" JOD","").str.replace(",","").astype(int)
# Out:
# C:\Users\Baku\AppData\Local\Temp\ipykernel_22228\4059287380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["Price"]=d["Price"].str.replace(" JOD","").str.replace(",","").astype(int)

# %%
d.groupby("Model")["Price"].mean().reset_index()
# Out:
#                            Model         Price
# 0                  Another April   3000.000000
# 1                    Another BMW  15325.000000
# 2                Another Hyundai   2933.333333
# 3                    Another Kia   5000.000000
# 4               Another Mahindra   3500.000000
# ..                           ...           ...
# 605  Volkswagen Touareg Elegance   4000.000000
# 606           Volkswagen e-tharu  11800.000000
# 607        Willys Gladiator Jeep  32000.000000
# 608                     Zicker X  28750.000000
# 609                       pocket  35500.000000
#
# [610 rows x 2 columns]

# %%
type(d["Price"][0])
# Out:
# numpy.int32

# %%
d.Price.mean()
# Out:
# 16141.087559808613

# %%
d.Price.std()
# Out:
# 15021.543660425396

# %%
d
# Out:
#         ID                       Model  Year   Condition  Fuel Type  \
# 0        1            Toyota Camry GLE  2023        used     Hybrid
# 1        2     BMW X5 Series xDrive40i  2020        used   gasoline
# 2        3  Mercedes-Benz SS-Class 320  2020  New (Zero)   gasoline
# 3        4     Toyota Land Cruiser VXR  2014        used   gasoline
# 4        5        Jeep Gladiator Sport  2021  New (Zero)   gasoline
# ...    ...                         ...   ...         ...        ...
# 2090  2091       Mitsubishi Galant GTS  2006        used   gasoline
# 2091  2092       Renault Clio Standard  2009        used   gasoline
# 2092  2093                      Daewoo  1997        used   gasoline
# 2093  2094             Ford Fusion SEL  2018        used     Hybrid
# 2094  2095                    Zicker X  2024  New (Zero)  undefined
#
#                    Mileage Seller Type             Location  Price  \
# 0       70,000 - 79,999 km  subjective       Ramtha, Ramtha  22500
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x="Year", y="Price", data=d)
plt.show()

# %%
plt.figure(figsize=(20, 14))
plt.plot(d['Year'], d['Price'], marker='o')

# Adding title and labels
plt.title('Sales Over Year')
plt.xlabel('Year')
plt.ylabel('Price')

plt.show()

# %%
sns.boxplot(x="Transmission", y="Price", data=d)
plt.show()

# %%
plt.figure(figsize=(35, 6))
plt.plot(a['Location'], a["Price"])

plt.title('Sales with Locaton')
plt.xlabel('Location')
plt.ylabel('Price')
sns.countplot(x="Location", data=d)
plt.xticks(rotation=90)
plt.show()

# %%
a=d.groupby("Location")["Price"].mean().reset_index()

# %%
a
# Out:
#                               Location         Price
# 0                         Ajloun, Abin   7937.500000
# 1                Ajloun, Al-Hashimiyah   7200.000000
# 2                       Ajloun, Anjara   4737.500000
# 3                        Ajloun, other   1950.000000
# 4                         Ajloun, rock  10100.000000
# ..                                 ...           ...
# 237             Zarqa, Refinery Street  28550.000000
# 238                    Zarqa, Russeifa   9433.333333
# 239                      Zarqa, Sokhna   4433.333333
# 240  Zarqa, Talal Housing - Al-Rusaifa   9200.000000
# 241                  Zarqa, the market  13500.000000
#
# [242 rows x 2 columns]

# %%
d
# Out:
#         ID                       Model  Year   Condition  Fuel Type  \
# 0        1            Toyota Camry GLE  2023        used     Hybrid
# 1        2     BMW X5 Series xDrive40i  2020        used   gasoline
# 2        3  Mercedes-Benz SS-Class 320  2020  New (Zero)   gasoline
# 3        4     Toyota Land Cruiser VXR  2014        used   gasoline
# 4        5        Jeep Gladiator Sport  2021  New (Zero)   gasoline
# ...    ...                         ...   ...         ...        ...
# 2090  2091       Mitsubishi Galant GTS  2006        used   gasoline
# 2091  2092       Renault Clio Standard  2009        used   gasoline
# 2092  2093                      Daewoo  1997        used   gasoline
# 2093  2094             Ford Fusion SEL  2018        used     Hybrid
# 2094  2095                    Zicker X  2024  New (Zero)  undefined
#
#                    Mileage Seller Type             Location  Price  \
# 0       70,000 - 79,999 km  subjective       Ramtha, Ramtha  22500
# ...

# %%
d["Mileage"]= d["Mileage"].str.replace("km", "").str.replace(",",  "").str.replace(" ", "").str.replace("KM", "")
# Out:
# C:\Users\Baku\AppData\Local\Temp\ipykernel_22228\921456048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["Mileage"]= d["Mileage"].str.replace("km", "").str.replace(",",  "").str.replace(" ", "").str.replace("KM", "")

# %%
m = d["Mileage"].str.split('-', expand = True)

# %%
d["Mileage"]=(m[0].astype(float) + m[1].astype(float))/2
# Out:
# C:\Users\Baku\AppData\Local\Temp\ipykernel_22228\2228448032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["Mileage"]=(m[0].astype(float) + m[1].astype(float))/2

# %%
d[d["Mileage"]==""]=0
# Out:
# C:\Users\Baku\AppData\Local\Temp\ipykernel_22228\1930762316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d[d["Mileage"]==""]=0

# %%
d
# Out:
#         ID                       Model  Year   Condition  Fuel Type   Mileage  \
# 0        1            Toyota Camry GLE  2023        used     Hybrid   74999.5
# 1        2     BMW X5 Series xDrive40i  2020        used   gasoline  104999.5
# 2        3  Mercedes-Benz SS-Class 320  2020  New (Zero)   gasoline   44999.5
# 3        4     Toyota Land Cruiser VXR  2014        used   gasoline  104999.5
# 4        5        Jeep Gladiator Sport  2021  New (Zero)   gasoline   34999.5
# ...    ...                         ...   ...         ...        ...       ...
# 2090  2091       Mitsubishi Galant GTS  2006        used   gasoline       NaN
# 2091  2092       Renault Clio Standard  2009        used   gasoline       NaN
# 2092  2093                      Daewoo  1997        used   gasoline   94999.5
# 2093  2094             Ford Fusion SEL  2018        used     Hybrid  154999.5
# 2094  2095                    Zicker X  2024  New (Zero)  undefined       NaN
#
# ...

# %%
d["Mileage"].corr(d["Price"])
# Out:
# -0.27002300283346026

# %%
plt.figure(figsize=(20,6))
sns.barplot(d, x="Color", y="Price")
# Out:
# <Axes: xlabel='Color', ylabel='Price'>

# %%
import plotly.express as px
fig = px.scatter(d, x="Year", y="Price", color="Model")
fig.update_xaxes(range=[1980, 2026])
fig.show()

# %%
d["Year"].unique()
# Out:
# array([2023, 2020, 2014, 2021, 2019, 2017, 2003, 2006, 2022, 2016, 2010,
#        2012, 2018, 2015, 2004, 2008, 2009, 2005, 2024, 2025, 2000, 2011,
#        2013, 1988, 2002, 2007, 1992, 1997, 1965,    0, 1991, 1990, 1994,
#        1995, 2001, 1993, 1999, 1996, 1998, 1987, 1986], dtype=int64)
